# %%
# Out:
# Epoch [20/100], Loss: 1.4331
# Epoch [40/100], Loss: 0.8530
# Epoch [60/100], Loss: 0.5519
# Epoch [80/100], Loss: 0.3949
# Epoch [100/100], Loss: 0.3126
#
# Parameter sebenarnya: y = 2.5x + 1.0
# Parameter hasil training: y = 2.10x + 0.92

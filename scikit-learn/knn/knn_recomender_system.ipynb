# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "anime.csv"

# Load the latest version
df_anime = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "hernan4444/anime-recommendation-database-2020",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # 
)
# Out:
# /tmp/ipython-input-2805001707.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df_anime = kagglehub.load_dataset(
# ...
# 100%|██████████| 1.96M/1.96M [00:00<00:00, 119MB/s]
# Extracting zip of anime.csv...

# %%
file_path = "anime_with_synopsis.csv"

# Load the latest version
df_anime_synop = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "hernan4444/anime-recommendation-database-2020",
  file_path,
)
# Out:
# /tmp/ipython-input-1057950307.py:4: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df_anime_synop = kagglehub.load_dataset(
# ...
# 100%|██████████| 2.75M/2.75M [00:00<00:00, 107MB/s]
# Extracting zip of anime_with_synopsis.csv...

# %%
file_path = "animelist.csv"

# Load the latest version
df_anime_list = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "hernan4444/anime-recommendation-database-2020",
  file_path,
)
# Out:
# /tmp/ipython-input-3902769696.py:4: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df_anime_list = kagglehub.load_dataset(
# ...
# 100%|██████████| 453M/453M [00:07<00:00, 61.4MB/s]
# Extracting zip of animelist.csv...

# %%
file_path = "rating_complete.csv"

# Load the latest version
df_anime_rating = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "hernan4444/anime-recommendation-database-2020",
  file_path,
)
# Out:
# /tmp/ipython-input-2817684781.py:4: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df_anime_rating = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'anime-recommendation-database-2020' dataset.

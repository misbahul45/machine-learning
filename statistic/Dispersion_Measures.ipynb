# %% [markdown]
# # Variance

# %% [markdown]
# # Standard Deviation

# %% [markdown]
# # Range

# %% [markdown]
# # Interquatile Range

# %% [markdown]
# # Mean Absolute Deviation

# %% [markdown]
# # Coefficient Of Variance

# %% [markdown]
# #
